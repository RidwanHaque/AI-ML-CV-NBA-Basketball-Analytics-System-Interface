# %% [markdown]
# # Install Libraries

# %% [markdown]
# ### YOLO is in the ultralytics library and we want to retrain YOLO. we are downloading and unzipping dataset in this notebook

# %%
# !pip install roboflow
# !pip install ultralytics
# Out:
# Collecting roboflow
#   Downloading roboflow-1.2.0-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from roboflow) (2025.6.15)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from roboflow) (3.8.2)
# Requirement already satisfied: numpy>=1.18.5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from roboflow) (1.26.4)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from roboflow) (11.2.1)
# Collecting pillow-heif<2 (from roboflow)
#   Downloading pillow_heif-1.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Collecting pillow-avif-plugin<2 (from roboflow)
#   Downloading pillow_avif_plugin-1.5.2-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: python-dateutil in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from roboflow) (1.1.1)
# Requirement already satisfied: requests in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from roboflow) (2.32.4)
# Requirement already satisfied: six in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from roboflow) (2.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from roboflow) (6.0.2)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib->roboflow) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib->roboflow) (4.58.4)
# Requirement already satisfied: packaging>=20.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib->roboflow) (3.2.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from requests->roboflow) (3.4.2)
# Downloading roboflow-1.2.0-py3-none-any.whl (86 kB)
# Downloading idna-3.7-py3-none-any.whl (66 kB)
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 115.4 MB/s eta 0:00:0000:0100:01
# Downloading pillow_avif_plugin-1.5.2-cp310-cp310-manylinux_2_28_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 144.0 MB/s eta 0:00:00
# Downloading pillow_heif-1.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 130.8 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Installing collected packages: pillow-avif-plugin, filetype, pillow-heif, opencv-python-headless, idna, requests-toolbelt, roboflow
#   Attempting uninstall: idnam╺━━━━━━━━━━━━━━━━━━━━━━ 3/7 [opencv-python-headless]
#     Found existing installation: idna 3.10━━━━━━━━━━━━━━━━━━━━ 3/7 [opencv-python-headless]
#     Uninstalling idna-3.10:90m╺━━━━━━━━━━━━━━━━━━━━━━ 3/7 [opencv-python-headless]
#       Successfully uninstalled idna-3.10━━━━━━━━━━━━━━━━━━━━━━ 3/7 [opencv-python-headless]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [roboflow]5/7 [requests-toolbelt]]
# Successfully installed filetype-1.2.0 idna-3.7 opencv-python-headless-4.10.0.84 pillow-avif-plugin-1.5.2 pillow-heif-1.0.0 requests-toolbelt-1.0.0 roboflow-1.2.0
# Collecting ultralytics
#   Downloading ultralytics-8.3.162-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from ultralytics) (3.8.2)
# Collecting opencv-python>=4.6.0 (from ultralytics)
#   Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: pillow>=7.1.2 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from ultralytics) (2.7.0+cu128)
# Requirement already satisfied: torchvision>=0.9.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from ultralytics) (0.22.0+cu128)
# Requirement already satisfied: tqdm>=4.64.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from ultralytics) (7.0.0)
# Collecting py-cpuinfo (from ultralytics)
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Requirement already satisfied: pandas>=1.1.4 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from ultralytics) (2.1.4)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: six>=1.5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2025.6.15)
# Requirement already satisfied: filelock in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (4.14.0)
# Requirement already satisfied: sympy>=1.13.3 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (2025.5.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.61 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (12.8.61)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.57 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (12.8.57)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.57 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (12.8.57)
# Requirement already satisfied: nvidia-cudnn-cu12==9.7.1.26 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (9.7.1.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.3.14 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (12.8.3.14)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.41 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (11.3.3.41)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.55 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (10.3.9.55)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.2.55 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (11.7.2.55)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.7.53 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (12.5.7.53)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.55 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (12.8.55)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.61 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (12.8.61)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.0.11 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (1.13.0.11)
# Requirement already satisfied: triton==3.3.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.3.0)
# Requirement already satisfied: setuptools>=40.8.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from triton==3.3.0->torch>=1.8.0->ultralytics) (78.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.162-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 33.3 MB/s eta 0:00:00
# Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (63.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 160.3 MB/s eta 0:00:00a 0:00:01
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Installing collected packages: py-cpuinfo, opencv-python, ultralytics-thop, ultralytics
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [ultralytics] [ultralytics]n]
# Successfully installed opencv-python-4.11.0.86 py-cpuinfo-9.0.0 ultralytics-8.3.162 ultralytics-thop-2.0.14

# %% [markdown]
# # Get Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="HSdaLY8H2JRmF04BsJ0t")
project = rf.workspace("workspace-5ujvu").project("basketball-players-fy4c2-vfsuv")
version = project.version(17)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Basketball-Players-17 to yolov5pytorch:: 100%|██████████| 23029/23029 [00:00<00:00, 23978.98it/s]
# Extracting Dataset Version Zip to Basketball-Players-17 in yolov5pytorch:: 100%|██████████| 652/652 [00:00<00:00, 3718.06it/s]

# %% [markdown]
# # File Structure Reorganization specifically need to do this for the YOLOV5 Model

# %%
import shutil


shutil.move("Basketball-Players-17/train",
            "Basketball-Players-17/Basketball-Players-17/train",
           )


shutil.move("Basketball-Players-17/valid",
            "Basketball-Players-17/Basketball-Players-17/valid",
           )
# Out:
# 'Basketball-Players-17/Basketball-Players-17/valid'

# %% [markdown]
# # Train YOLO there are other tasks other than detection but all we need is detection and the mode is training as we are wanting to train the model

# %%
# !yolo task=detect mode=train model=yolov5l6u.pt data=Basketball-Players-17/data.yaml epochs=100 imgsz=640 plots=True batch=8
# dataset we passed is the one we downloaded from cell 2
# we take location and add yaml
# samples is how much we process at one time. so higher means faster training but takes more resources
# line above is all we need to fine tune YOLO model and have it train on custom dataset
# Epochs choose appropriate number based on what we are training
# box loss and classification loss are metrics for error
# Out:
# Ultralytics 8.3.162 🚀 Python-3.10.10 torch-2.7.0+cu128 CUDA:0 (Tesla T4, 14931MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=Basketball-Players-17/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov5l6u.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/detect/train2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/teamspace/studios/this_studio/.config/Ultralytics/Arial.ttf'...
# 100%|████████████████████████████████████████| 755k/755k [00:00<00:00, 14.7MB/s]
# Overriding model.yaml nc=80 with nc=7
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      7040  ultralytics.nn.modules.conv.Conv             [3, 64, 6, 2, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  3    156928  ultralytics.nn.modules.block.C3              [128, 128, 3]
#   3                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   4                  -1  6   1118208  ultralytics.nn.modules.block.C3              [256, 256, 6]
#   5                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   6                  -1  9   6433792  ultralytics.nn.modules.block.C3              [512, 512, 9]
#   7                  -1  1   3540480  ultralytics.nn.modules.conv.Conv             [512, 768, 3, 2]
#   8                  -1  3   5611008  ultralytics.nn.modules.block.C3              [768, 768, 3]
#   9                  -1  1   7079936  ultralytics.nn.modules.conv.Conv             [768, 1024, 3, 2]
#  10                  -1  3   9971712  ultralytics.nn.modules.block.C3              [1024, 1024, 3]
#  11                  -1  1   2624512  ultralytics.nn.modules.block.SPPF            [1024, 1024, 5]
#  12                  -1  1    787968  ultralytics.nn.modules.conv.Conv             [1024, 768, 1, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   6200832  ultralytics.nn.modules.block.C3              [1536, 768, 3, False]
#  16                  -1  1    394240  ultralytics.nn.modules.conv.Conv             [768, 512, 1, 1]
#  17                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  18             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  3   2757632  ultralytics.nn.modules.block.C3              [1024, 512, 3, False]
#  20                  -1  1    131584  ultralytics.nn.modules.conv.Conv             [512, 256, 1, 1]
#  21                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  22             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  23                  -1  3    690688  ultralytics.nn.modules.block.C3              [512, 256, 3, False]
#  24                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  25            [-1, 20]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  26                  -1  3   2495488  ultralytics.nn.modules.block.C3              [512, 512, 3, False]
#  27                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  28            [-1, 16]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  29                  -1  3   5807616  ultralytics.nn.modules.block.C3              [1024, 768, 3, False]
#  30                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#  31            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  32                  -1  3  10496000  ultralytics.nn.modules.block.C3              [1536, 1024, 3, False]
#  33    [23, 26, 29, 32]  1   9908524  ultralytics.nn.modules.head.Detect           [7, [256, 512, 768, 1024]]
# YOLOv5l6u summary: 314 layers, 86,024,876 parameters, 86,024,860 gradients, 137.7 GFLOPs
#
# Transferred 891/899 items from pretrained weights
# Freezing layer 'model.33.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|██████████████████████████████████████| 5.35M/5.35M [00:00<00:00, 73.0MB/s]
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1594.5±499.6 MB/s, size: 85.8 KB)
# train: Scanning /teamspace/studios/this_studio/Basketball-Players-17/Basketball-
# train: New cache created: /teamspace/studios/this_studio/Basketball-Players-17/Basketball-Players-17/train/labels.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 829.0±379.5 MB/s, size: 59.4 KB)
# val: Scanning /teamspace/studios/this_studio/Basketball-Players-17/Basketball-Pl
# val: New cache created: /teamspace/studios/this_studio/Basketball-Players-17/Basketball-Players-17/valid/labels.cache
# Plotting labels to runs/detect/train2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000909, momentum=0.9) with parameter groups 147 weight(decay=0.0), 156 weight(decay=0.0005), 155 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/detect/train2
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100         6G      1.461      2.294      1.461        124        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.347      0.516      0.432      0.243
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100       6.9G      1.236      1.282      1.254        120        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.395      0.703      0.354      0.207
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      6.97G      1.311      1.257      1.289        183        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.704      0.585      0.645      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      6.23G      1.321      1.218      1.305        145        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.821      0.622      0.708      0.421
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      6.85G      1.268      1.131      1.284        133        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.764       0.75      0.763      0.475
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      6.98G      1.271      1.088      1.291        177        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.831      0.708      0.796        0.5
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100       6.2G      1.199     0.9732      1.218        196        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.852      0.765      0.844      0.591
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      6.82G      1.155     0.9386      1.208        253        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.846      0.746      0.839      0.579
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      7.24G       1.14     0.9046      1.202        185        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.908       0.75      0.852      0.561
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      7.46G      1.154     0.9337       1.21        205        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.869      0.755      0.813      0.557
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      6.59G      1.117     0.8672      1.184        149        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.924      0.785      0.881      0.596
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      6.95G       1.11     0.8426      1.197        226        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.917      0.802      0.882       0.61
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      7.48G      1.065     0.8234      1.155        173        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.923      0.769      0.862      0.617
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      6.51G      1.073     0.8287      1.163        182        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.926      0.827      0.898      0.652
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      6.98G      1.022     0.7973      1.153        154        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.937      0.793       0.91       0.65
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      7.52G      1.017     0.7721       1.14        111        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.924      0.798       0.88      0.654
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      6.58G      1.042     0.7768      1.137        204        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.918      0.846      0.902       0.67
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100         7G      1.022     0.7707       1.13        112        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.931      0.809      0.909      0.635
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      6.07G      1.026     0.7602      1.132        168        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.892      0.857      0.913      0.652
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      6.44G      1.011     0.7649      1.129        149        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.894      0.842      0.914      0.643
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      6.97G     0.9799      0.732      1.112        221        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.903      0.883      0.924      0.686
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100       6.1G     0.9533     0.7017      1.092        236        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.881      0.863      0.918      0.689
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      6.48G     0.9387     0.6945      1.104        157        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.939      0.878       0.92      0.691
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      6.98G     0.9377     0.6894      1.096        187        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.906      0.879      0.917      0.684
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      6.16G     0.9655      0.712      1.103        180        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.896      0.841      0.904      0.657
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      6.78G     0.9442     0.6778       1.09        140        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.934      0.864      0.916      0.697
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      7.01G     0.9318     0.6788      1.093        231        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.907      0.876      0.914      0.687
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      6.12G     0.9136      0.669      1.076        125        640:

# %%
# !yolo task=detect mode=train resume=True model=runs/detect/train2/weights/last.pt
# Out:
# Ultralytics 8.3.162 🚀 Python-3.10.10 torch-2.7.0+cu128 CUDA:0 (Tesla T4, 14931MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=Basketball-Players-17/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=runs/detect/train2/weights/last.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=runs/detect/train2/weights/last.pt, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/detect/train2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.0, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      7040  ultralytics.nn.modules.conv.Conv             [3, 64, 6, 2, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  3    156928  ultralytics.nn.modules.block.C3              [128, 128, 3]
#   3                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   4                  -1  6   1118208  ultralytics.nn.modules.block.C3              [256, 256, 6]
#   5                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   6                  -1  9   6433792  ultralytics.nn.modules.block.C3              [512, 512, 9]
#   7                  -1  1   3540480  ultralytics.nn.modules.conv.Conv             [512, 768, 3, 2]
#   8                  -1  3   5611008  ultralytics.nn.modules.block.C3              [768, 768, 3]
#   9                  -1  1   7079936  ultralytics.nn.modules.conv.Conv             [768, 1024, 3, 2]
#  10                  -1  3   9971712  ultralytics.nn.modules.block.C3              [1024, 1024, 3]
#  11                  -1  1   2624512  ultralytics.nn.modules.block.SPPF            [1024, 1024, 5]
#  12                  -1  1    787968  ultralytics.nn.modules.conv.Conv             [1024, 768, 1, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   6200832  ultralytics.nn.modules.block.C3              [1536, 768, 3, False]
#  16                  -1  1    394240  ultralytics.nn.modules.conv.Conv             [768, 512, 1, 1]
#  17                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  18             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  3   2757632  ultralytics.nn.modules.block.C3              [1024, 512, 3, False]
#  20                  -1  1    131584  ultralytics.nn.modules.conv.Conv             [512, 256, 1, 1]
#  21                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  22             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  23                  -1  3    690688  ultralytics.nn.modules.block.C3              [512, 256, 3, False]
#  24                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  25            [-1, 20]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  26                  -1  3   2495488  ultralytics.nn.modules.block.C3              [512, 512, 3, False]
#  27                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  28            [-1, 16]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  29                  -1  3   5807616  ultralytics.nn.modules.block.C3              [1024, 768, 3, False]
#  30                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#  31            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  32                  -1  3  10496000  ultralytics.nn.modules.block.C3              [1536, 1024, 3, False]
#  33    [23, 26, 29, 32]  1   9908524  ultralytics.nn.modules.head.Detect           [7, [256, 512, 768, 1024]]
# YOLOv5l6u summary: 314 layers, 86,024,876 parameters, 86,024,860 gradients, 137.7 GFLOPs
#
# Transferred 899/899 items from pretrained weights
# Freezing layer 'model.33.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1671.1±530.6 MB/s, size: 85.8 KB)
# train: Scanning /teamspace/studios/this_studio/Basketball-Players-17/Basketball-
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read:
126        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.967      0.855      0.944      0.735
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      6.22G     0.7108     0.4935     0.9812         98        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483       0.98      0.824      0.946       0.74
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      6.61G     0.7085      0.482     0.9752        169        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.893      0.893      0.939      0.746
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      7.27G      0.692     0.4858      0.982        224        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.942      0.876      0.929      0.745
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      7.52G     0.6976     0.4771     0.9765        128        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.966       0.86      0.932      0.739
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      6.56G     0.6913     0.4749     0.9747        188        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.926      0.885      0.936      0.749
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      6.99G     0.6867     0.4666     0.9685        144        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.956      0.865      0.935      0.747
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      6.15G     0.6827     0.4702     0.9713        231        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.888      0.911      0.939      0.752
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      6.52G      0.682      0.463     0.9679        173        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.943      0.859      0.933      0.749
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      6.96G     0.6714     0.4581     0.9643        124        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.927      0.874      0.937      0.752
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      7.46G     0.6668      0.458     0.9569        136        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.937      0.877      0.937      0.754
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      6.58G     0.6727      0.461     0.9648        170        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.957      0.872      0.934      0.743
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      7.25G     0.6678     0.4614     0.9627        162        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.968      0.859      0.927      0.739
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      7.43G     0.6581     0.4418     0.9574        114        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.955      0.871      0.939      0.745
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      6.52G     0.6557     0.4413     0.9535        183        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483       0.88      0.936      0.942      0.751
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      7.18G      0.631     0.4278     0.9469        202        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483        0.9      0.901      0.939      0.755
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      7.44G     0.6582     0.4447     0.9572        177        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.948      0.873      0.943      0.751
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      6.55G     0.6483     0.4419      0.953        227        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.971      0.836      0.944      0.754
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      6.96G     0.6269     0.4327     0.9458        177        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.907       0.92      0.955      0.763
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100       6.1G     0.6335     0.4247     0.9386        211        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.921      0.916      0.954      0.758
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      6.47G     0.6252     0.4242     0.9459        118        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.979      0.872      0.953      0.761
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      6.94G     0.6178     0.4224     0.9454        183        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.983      0.882      0.952      0.762
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      6.08G     0.5809     0.3903     0.9204        100        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.964      0.882      0.949       0.76
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      6.46G     0.5608     0.3664     0.9091         92        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483       0.96      0.878      0.947      0.751
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      6.89G     0.5497     0.3608     0.9078        101        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.972      0.875      0.949      0.763
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      7.37G     0.5535     0.3641     0.9061        104        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.965      0.867      0.943      0.764
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      6.52G     0.5581     0.3664     0.9101        110        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.943      0.891      0.944      0.763
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      6.92G     0.5465     0.3579     0.9025        120        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.943      0.895      0.944      0.765
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      7.36G     0.5338     0.3502     0.8969        101        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.956      0.887      0.943      0.763
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      6.53G     0.5431     0.3537     0.9082        112        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.973      0.877      0.942      0.764
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      6.88G     0.5357     0.3446     0.9006        128        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.975      0.878      0.941      0.762
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      7.43G     0.5281     0.3507     0.8939        120        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.973       0.88      0.942      0.763
#
# 73 epochs completed in 0.330 hours.
# Optimizer stripped from runs/detect/train2/weights/last.pt, 172.7MB
# Optimizer stripped from runs/detect/train2/weights/best.pt, 172.7MB
#
# Validating runs/detect/train2/weights/best.pt...
# Ultralytics 8.3.162 🚀 Python-3.10.10 torch-2.7.0+cu128 CUDA:0 (Tesla T4, 14931MiB)
# YOLOv5l6u summary (fused): 167 layers, 85,978,476 parameters, 0 gradients, 137.0 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         32        483      0.945      0.895      0.944      0.765
#                   Ball         28         28      0.941      0.568      0.751      0.457
#                  Clock         24         35      0.988      0.971       0.98      0.863
#                   Hoop         29         30          1      0.925      0.989       0.78
#                Overlay         28         40      0.772      0.975      0.977      0.792
#                 Player         32        259      0.951      0.904      0.959      0.743
#                    Ref         29         64      0.967       0.92      0.957       0.76
#             Scoreboard         27         27      0.998          1      0.995      0.959
# Speed: 0.2ms preprocess, 17.5ms inference, 0.0ms loss, 1.7ms postprocess per image
# Results saved to runs/detect/train2
# 💡 Learn more at https://docs.ultralytics.com/modes/train
